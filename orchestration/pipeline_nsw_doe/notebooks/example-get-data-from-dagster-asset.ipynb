# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import dagstermill
from dagster import AssetKey

from orchestration.pipeline_nsw_doe import defs

# %%
context = dagstermill.get_context(op_config=3)

# %%
df = defs.load_asset_value(AssetKey(['analytics','metrics_by_year_school_saved_query']))
df
# Out:
#       metric_time__year           school__school_name  \
# 0            2024-01-01     Albion Park Public School
# 1            2024-01-01         Arcadia Public School
# 2            2024-01-01    Auburn North Public School
# 3            2024-01-01         Barooga Public School
# 4            2024-01-01      Barrington Public School
# ...                 ...                           ...
# 15396        2025-01-01          Cronulla High School
# 15397        2025-01-01         Boambee Public School
# 15398        2025-01-01          Camden Public School
# 15399        2025-01-01       Tallawong Public School
# 15400        2025-01-01  Marayong South Public School
#
#        school__latest_year_enrolment_fte school__level_of_schooling  \
# 0                                  490.0             Primary School
# 1                                   71.0             Primary School
# 2                                  637.0             Primary School
# 3                                   89.0             Primary School
# 4                                   53.0             Primary School
# ...                                  ...                        ...
# 15396                             1239.0           Secondary School
# 15397                              349.0             Primary School
# 15398                              310.0             Primary School
# 15399                                NaN             Primary School
# 15400                              296.0             Primary School
#
#        school__icsea_value school__indigenous_pct school__selective_school  \
# 0                    977.0                   11.0            Not Selective
# 1                   1058.0                     np            Not Selective
# 2                   1007.0                    0.0            Not Selective
# 3                    972.0                     np            Not Selective
# 4                    991.0                   15.0            Not Selective
# ...                    ...                    ...                      ...
# 15396               1048.0                    3.0            Not Selective
# 15397               1003.0                   12.0            Not Selective
# 15398               1040.0                    5.0            Not Selective
# 15399                  NaN                   None            Not Selective
# 15400               1010.0                    9.0            Not Selective
#
#       school__school_specialty_type  funding_aud_post_adjustments  \
# 0                     Comprehensive                           NaN
# 1                     Comprehensive                           NaN
# 2                     Comprehensive                           NaN
# 3                     Comprehensive                           NaN
# 4                     Comprehensive                           NaN
# ...                             ...                           ...
# 15396                 Comprehensive                           NaN
# 15397                 Comprehensive                           NaN
# 15398                 Comprehensive                           NaN
# 15399                 Comprehensive                           NaN
# 15400                 Comprehensive                           NaN
#
#        funding_aud_original  funding_aud_post_adjustments_prev_year
# 0                  685082.0                                695548.0
# 1                   68533.0                                 75837.0
# 2                 1317605.0                               1491270.0
# 3                  141741.0                                182176.0
# 4                   82946.0                                 82935.0
# ...                     ...                                     ...
# 15396                   NaN                                     NaN
# 15397                   NaN                                     NaN
# 15398                   NaN                                     NaN
# 15399                   NaN                                     NaN
# 15400                   NaN                                     NaN
#
# [15401 rows x 11 columns]
